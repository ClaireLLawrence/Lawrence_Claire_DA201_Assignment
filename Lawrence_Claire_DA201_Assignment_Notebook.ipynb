# %%
# Pandas,NumPy, Matplotlib and Seaborn are imported ready for analysis.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/Claire/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Data Import and Sense-Checking

# %%
# The actual_duration.csv file is imported as a DataFrame. The file is comma-delimited and has headers.
ad = pd.read_csv('actual_duration.csv')

# The data is sense-checked after import to check it has imported correctly.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# The shape is checked to understand how many rows and columns there are.
# Data types for all columns are also sense-checked.
print(ad.shape)
print(ad.dtypes)
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
# The data is checked for any null values that might interfere with analysis.
ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Categories within the actual_duration column are sense-checked to see what they are.
print(ad['actual_duration'].unique())
# Out:
# ['31-60 Minutes' '21-30 Minutes' '6-10 Minutes' 'Unknown / Data Quality'
#  '16-20 Minutes' '11-15 Minutes' '1-5 Minutes']

# %%
# Next, the appointments_regional.csv file is imported as a DataFrame.
# This file is also comma-delimited with headers.
ar = pd.read_csv('appointments_regional.csv')

# The file is sense-checked to ensure correct importation.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# The shape is checked to understand how many rows and columns there are.
# Data types for all columns are also sense-checked.
print(ar.shape)
print(ar.dtypes)
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# The data is checked for any null values that might interfere with analysis.
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Next, the national_categories.xlsx file is imported as a DataFrame.
# This is an Excel file with headers.
nc = pd.read_excel('national_categories.xlsx')

# The data is sense-checked to make sure it has imported correctly.
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# The shape is checked to understand how many rows and columns there are.
# Data types for all columns are also sense-checked.
print(nc.shape)
print(nc.dtypes)
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# The data is checked for any null values that might interfere with analysis.
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# The descriptive statistics for the ad DataFrame are called.
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Metadata for the ad DataFrame is also called.
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# The descriptive statistics for the ar DataFrame are called.
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Metadata for the ar DataFrame is also called.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# The 'time_between_book_and_appointment' column is sense-checked to see what it contains.
print(ar['time_between_book_and_appointment'].unique())
# Out:
# ['1 Day' '15  to 21 Days' '2 to 7 Days' '22  to 28 Days' '8  to 14 Days'
#  'More than 28 Days' 'Same Day' 'Unknown / Data Quality']

# %%
# The descriptive statistics for the nc DataFrame are called.
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %%
# Metadata for the nc DataFrame is also called.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Code is written to print the number of unique locations in the data set.
# This is done by counting the location names in the nc DataFrame.
print("Count of Locations: ",len(nc['sub_icb_location_name'].unique()))
# Out:
# Count of Locations:  106

# %%
# The total number of different categories within each of the below columns are counted.
print("Total service_setting Categories: ",(len(nc['service_setting'].value_counts())))
print("Total context_type Categories: ",(len(nc['context_type'].value_counts())))
print("Total national_category Categories: ",(len(nc['national_category'].value_counts())))
print("Total appointment_status Categories: ",(len(ar['appointment_status'].value_counts())))
# Out:
# Total service_setting Categories:  5
# Total context_type Categories:  3
# Total national_category Categories:  18
# Total appointment_status Categories:  3

# %%
# The categories are listed to understand what they contain.
print("All service_setting Categories: ",(nc['service_setting'].unique()))
print("All context_type Categories: ",(nc['context_type'].unique()))
print("All national_category Categories: ",(nc['national_category'].unique()))
print("All appointment_status Categories: ",(ar['appointment_status'].unique()))
# Out:
# All service_setting Categories:  ['Primary Care Network' 'Other' 'General Practice' 'Unmapped'
#  'Extended Access Provision']
# All context_type Categories:  ['Care Related Encounter' 'Unmapped' 'Inconsistent Mapping']
# All national_category Categories:  ['Patient contact during Care Home Round' 'Planned Clinics' 'Home Visit'
#  'General Consultation Acute' 'Structured Medication Review'
#  'Care Home Visit' 'Unmapped' 'Clinical Triage'
#  'Planned Clinical Procedure' 'Inconsistent Mapping'
#  'Care Home Needs Assessment & Personalised Care and Support Planning'
#  'General Consultation Routine'
#  'Service provided by organisation external to the practice'
#  'Unplanned Clinical Activity' 'Social Prescribing Service'
#  'Non-contractual chargeable work'
#  'Group Consultation and Group Education' 'Walk-in']
# All appointment_status Categories:  ['Attended' 'DNA' 'Unknown']

# %%
# The nc DataFrame is subset to understand the service setting breakdown.
# This shows that General Practice is the most common category.
setting_apps = nc.groupby(['service_setting'])['count_of_appointments'].agg('sum').reset_index()
print(setting_apps)
# Out:
#              service_setting  count_of_appointments
# 0  Extended Access Provision                2176807
# 1           General Practice              270811691
# 2                      Other                5420076
# 3       Primary Care Network                6557386
# 4                   Unmapped               11080810

# %% [markdown]
# Data Formats Checked/Amended and Date Range Ascertained

# %%
# Date formats: ad has appointment_date in object format, while nc has appointment_date in datetime64 format.
# The formats are viewed in both DataFrames to see how they appear.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# datetime is imported. The type is changed in the ad DataFrame from a string to the datetime64 format.
from datetime import datetime

ad['appointment_date'] = ad['appointment_date'].astype('datetime64[ns]')

# %%
# The data types are checked to make sure the change was successful.
print(ad.dtypes)
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object

# %%
# The date in the ad DataFrame is then reformatted to dd-mm-yyyy.
ad['appointment_date'] = ad['appointment_date'].dt.strftime('%d-%m-%Y')
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       01-12-2021           31-60 Minutes                    364
# 1       01-12-2021           21-30 Minutes                    619
# ...

# %%
# The date in the nc DataFrame is now also reformatted to dd-mm-yyyy for consistency.
# Both DataFrames now have the date in the same format and data type.
nc['appointment_date'] = nc['appointment_date'].dt.strftime('%d-%m-%Y')

# %%
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       02-08-2021    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       02-08-2021    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       02-08-2021    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       02-08-2021    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       02-08-2021    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# The appointment month is changed from a string to a date.
nc['appointment_month'] = nc['appointment_month'].astype('datetime64[ns]')
nc['appointment_month'] = nc['appointment_month'].dt.strftime('%m-%Y')

# %%
# The months are printed to check the dates covered.

print(nc['appointment_month'].value_counts())
# Out:
# 03-2022    82822
# 11-2021    77652
# 05-2022    77425
# 09-2021    74922
# 06-2022    74168
# 10-2021    74078
# 12-2021    72651
# 01-2022    71896
# 02-2022    71769
# 04-2022    70012
# 08-2021    69999
# Name: appointment_month, dtype: int64

# %%
# The data is sorted in both DataFrames to check date range of the data.
ad.sort_index()
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# ...

# %%
nc.sort_index()
# Out:
#        appointment_date icb_ons_code  \
# 0            02-08-2021    E54000050
# 1            02-08-2021    E54000050
# 2            02-08-2021    E54000050
# 3            02-08-2021    E54000050
# 4            02-08-2021    E54000050
# ...                 ...          ...
# 817389       30-06-2022    E54000054
# 817390       30-06-2022    E54000054
# 817391       30-06-2022    E54000054
# 817392       30-06-2022    E54000054
# 817393       30-06-2022    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
# The format of the 'count_of_appointments' column is changed to integer for analysis.
nc['count_of_appointments'] = nc['count_of_appointments'].astype('int64')

# %% [markdown]
# Identify The Locations with Most/Least Appointments

# %%
# A sub-set of data is created to see which are the icb locations with the most and the least appointments.
most_apps = nc.groupby(['sub_icb_location_name'])['count_of_appointments'
                                                 ].agg('sum').sort_values(ascending=False).reset_index()
print(most_apps)

# The top 5 locations are added to a variable to create a chart.
most_apps_chart = most_apps.head(5)
# Out:
#                             sub_icb_location_name  count_of_appointments
# 0               NHS North West London ICB - W2U3Z               12142390
# 1               NHS North East London ICB - A3A8R                9588891
# 2                   NHS Kent and Medway ICB - 91Q                9286167
# 3     NHS Hampshire and Isle Of Wight ICB - D9Y0V                8288102
# 4                 NHS South East London ICB - 72Q                7850170
# ..                                            ...                    ...
# 101         NHS Cheshire and Merseyside ICB - 01V                 641149
# 102  NHS Nottingham and Nottinghamshire ICB - 02Q                 639660
# 103              NHS Greater Manchester ICB - 00V                 639211
# 104         NHS Cheshire and Merseyside ICB - 01T                 606606
# 105    NHS Lancashire and South Cumbria ICB - 02G                 554694
#
# [106 rows x 2 columns]

# %%
# A new subset DataFrame is created to identify the code for NHS North West London ICB - W2U3Z.
# This contains all locations and codes and is then filtered, to just show this location.
# Only one row needs to be printed.
location_codes = pd.read_excel('national_categories.xlsx', usecols=['icb_ons_code', 'sub_icb_location_name'])

nwl = location_codes[location_codes['sub_icb_location_name'] == 'NHS North West London ICB - W2U3Z']

print(nwl.head(1))
# Out:
#        icb_ons_code              sub_icb_location_name
# 794321    E54000027  NHS North West London ICB - W2U3Z

# %%
# A barplot is created to show the top five locations (using the most_apps_chart variable created earlier).

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(25, 20)})
ax.set_title("Locations with Highest Number of Appointments")
ax.set_xlabel("Location Name")
ax.set_ylabel("Total Appointments")

sns.barplot(x='sub_icb_location_name', y='count_of_appointments', estimator=sum, data=most_apps_chart)

# Labels showing the count of each bar are added to the chart.
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')

# The chart is saved to add to the report.
# Whilst x labels overlap here, they appear fine in the png file.
fig.savefig('highest_appointments_bar.png')

# %%
# The split between service settings for the top location is counted.
# First, the nc DataFrame is filtered.
top_nwl = nc[nc['sub_icb_location_name'] == 'NHS North West London ICB - W2U3Z']

top_nwl_setting = top_nwl.groupby(['service_setting'
                                  ])['count_of_appointments'].agg('sum').sort_values(ascending=False).reset_index()
print(top_nwl_setting)
# Out:
#              service_setting  count_of_appointments
# 0           General Practice               10432225
# 1                   Unmapped                 904234
# 2                      Other                 343642
# 3       Primary Care Network                 240283
# 4  Extended Access Provision                 222006

# %%
# The same is then done for the bottom location.
# The same trend is visible across both locations.
bottom_lsc = nc[nc['sub_icb_location_name'] == 'NHS Lancashire and South Cumbria ICB - 02G']

bottom_lsc_setting = bottom_lsc.groupby(['service_setting'
                                        ])['count_of_appointments'].agg('sum').sort_values(ascending=False).reset_index()
print(bottom_lsc_setting)
# Out:
#              service_setting  count_of_appointments
# 0           General Practice                 532833
# 1       Primary Care Network                  12072
# 2                   Unmapped                   6954
# 3  Extended Access Provision                   1528
# 4                      Other                   1307

# %%
# A further dataset obtained from digital.nhs.uk shows the number of GPs in each ICB.
# Calculation: Number of GPs in top icb % number in bottom icb.
# This shows that there are 26 times more in the top one than lower one.
1638 % 62
# Out:
# 26

# %%
# Now the data is sub-set to create a chart for the bottom five locations.
least_apps = nc.groupby(['sub_icb_location_name'])['count_of_appointments'].agg('sum').sort_values(ascending=True).reset_index()
print(least_apps)

least_apps_chart = least_apps.head(5)
# Out:
#                             sub_icb_location_name  count_of_appointments
# 0      NHS Lancashire and South Cumbria ICB - 02G                 554694
# 1           NHS Cheshire and Merseyside ICB - 01T                 606606
# 2                NHS Greater Manchester ICB - 00V                 639211
# 3    NHS Nottingham and Nottinghamshire ICB - 02Q                 639660
# 4           NHS Cheshire and Merseyside ICB - 01V                 641149
# ..                                            ...                    ...
# 101               NHS South East London ICB - 72Q                7850170
# 102   NHS Hampshire and Isle Of Wight ICB - D9Y0V                8288102
# 103                 NHS Kent and Medway ICB - 91Q                9286167
# 104             NHS North East London ICB - A3A8R                9588891
# 105             NHS North West London ICB - W2U3Z               12142390
#
# [106 rows x 2 columns]

# %%
# A barplot is generated, the same as for the top locations.
fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(15, 15)})
ax.set_title("Locations with Lowest Number of Appointments")
ax.set_xlabel("Location Name")
ax.set_ylabel("Total Appointments")

sns.barplot(x='sub_icb_location_name', y='count_of_appointments', estimator=sum, data=least_apps_chart)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')

fig.savefig('lowest_appointments_bar.png')

# %% [markdown]
# Trends Across the Whole Dataset

# %%
# Taking all the data as a whole (using the nc DataFrame), the service setting category across all the data
# is charted to see if the trend applies across all the data.
# The same trend (i.e. General Practice the largest category) is indeed evident.
fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Appointments by Service Setting")
ax.set_xlabel("Service Setting")
ax.set_ylabel("Total Appointments")

sns.barplot(x='service_setting', y='count_of_appointments', estimator=sum, data=nc)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')
    
fig.savefig('total_appointments_service_setting_bar.jpg')

# %%
# A lineplot is created visualising the context type over time.
# The categories do not prove to be very useful for analysis.
fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(12, 15)})
ax.set_title("Total Appointments by Month by Context Type")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90) # x-axis labels are rotated 90 degrees to be more readble.

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='context_type', estimator=sum, data=nc)
# Out:
# <AxesSubplot:title={'center':'Total Appointments by Month by Context Type'}, xlabel='Appointment Month', ylabel='Total Appointments'>

# %%
fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(12, 15)})
ax.set_title("Total Appointments by Month by Service Setting")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)
plt.axhline(y=36000000, color='r', linestyle='--')

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='service_setting', estimator=sum, data=nc)
# Out:
# <AxesSubplot:title={'center':'Total Appointments by Month by Service Setting'}, xlabel='Appointment Month', ylabel='Total Appointments'>

# %%
# The same is done to visualise the national category over time.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(12, 15)})
ax.set_title("Total Appointments by Month by National Category")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='national_category', estimator=sum, data=nc)
# Out:
# <AxesSubplot:title={'center':'Total Appointments by Month by National Category'}, xlabel='Appointment Month', ylabel='Total Appointments'>

# %%
# Book/wait time is aggregated to see how long, in general, patients wait for an appointment.

book_time = ar.groupby(['time_between_book_and_appointment'
                       ])['count_of_appointments'].agg('sum').sort_values(ascending=False).reset_index()

print(book_time)
# Out:
#   time_between_book_and_appointment  count_of_appointments
# 0                          Same Day              342747171
# 1                       2 to 7 Days              153794531
# 2                     8  to 14 Days               86846519
# 3                             1 Day               67716097
# 4                    15  to 21 Days               42710574
# 5                    22  to 28 Days               25536541
# 6                 More than 28 Days               23050987
# 7            Unknown / Data Quality                 402105

# %%
#Appointments are also counted by month.

month_apps = ar.groupby(['appointment_month'])['count_of_appointments'].agg('sum').reset_index()

print(month_apps)
# Out:
#    appointment_month  count_of_appointments
# 0            2020-01               27199296
# 1            2020-02               24104621
# 2            2020-03               24053468
# 3            2020-04               16007881
# 4            2020-05               16417212
# 5            2020-06               20690805
# 6            2020-07               22491437
# 7            2020-08               20150520
# 8            2020-09               26714255
# 9            2020-10               28301932
# 10           2020-11               25061602
# 11           2020-12               23535936
# 12           2021-01               22492069
# 13           2021-02               22399569
# 14           2021-03               27225424
# 15           2021-04               23879932
# 16           2021-05               23508395
# 17           2021-06               26784182
# 18           2021-07               25739219
# 19           2021-08               23852171
# ...

# %%
# A lineplot is now created to visualise all the appointments by month.
# The trend is an upward one, with a big dip around the peak COVID lockdown.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Appointments by Month")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)

sns.lineplot(x='appointment_month', y='count_of_appointments', estimator=sum, data=ar, ci=None)

fig.savefig('total_appointments_by_month.jpg')

# %% [markdown]
# Unattended Appointments and Statistics

# %%
# Data is sub-set to see breakdown between appointment status categories.

hcp_status = ar.groupby(['appointment_month','appointment_status'
                        ])['count_of_appointments'].agg('sum').reset_index()

print(hcp_status)
# Out:
#    appointment_month appointment_status  count_of_appointments
# 0            2020-01           Attended               24538291
# 1            2020-01                DNA                1298269
# 2            2020-01            Unknown                1362736
# 3            2020-02           Attended               21640067
# 4            2020-02                DNA                1215154
# ..               ...                ...                    ...
# 85           2022-05                DNA                1199518
# 86           2022-05            Unknown                 952049
# 87           2022-06           Attended               23715317
# 88           2022-06                DNA                1167790
# 89           2022-06            Unknown                 944971
#
# [90 rows x 3 columns]

# %%
# A barplot is then created to visualise the categories by HCP type.
# Most appointments are indeed attended across all HCP types.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Appointments by HCP Type and Status")
ax.set_xlabel("HCP Type")
ax.set_ylabel("Total Appointments")

sns.barplot(x='hcp_type', y='count_of_appointments', hue='appointment_status', estimator=sum, data=ar)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')


fig.savefig('total_appointments_status_hcp_bar.jpg')

# %%
# The ar DataFrame is then filtered to only contain appointments recorded as unattended.

no_attend = ar[ar['appointment_status'] == 'DNA']

print(no_attend)

# The data is then grouped and viewed by month, to create a chart.
hcp_status = no_attend.groupby(['appointment_month',
                                'appointment_status'])['count_of_appointments'].agg('sum').reset_index()

print(hcp_status)
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 69        E54000034           2020-01                DNA       GP
# 70        E54000034           2020-01                DNA       GP
# 71        E54000034           2020-01                DNA       GP
# 72        E54000034           2020-01                DNA       GP
# 73        E54000034           2020-01                DNA       GP
# ...             ...               ...                ...      ...
# 596756    E54000050           2022-06                DNA  Unknown
# 596757    E54000050           2022-06                DNA  Unknown
# 596758    E54000050           2022-06                DNA  Unknown
# 596759    E54000050           2022-06                DNA  Unknown
# 596760    E54000050           2022-06                DNA  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 69         Face-to-Face                             1 Day
# ...

# %%
# A lineplot is created to visualise the unattended appointments over time.
# It appears that 'Other Practice Staff' appointments regularly experience the most missed appointments.
# It's not clear from current datasets why this might be.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Non-Attended Appointments by HCP Type")
ax.set_xlabel("Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type', estimator=sum, data=no_attend)

fig.savefig('unattended_appointments_by_month_and_hcp.png')

# %%
# A further barplot is created to see how HCP type relates to book/wait time.
# Appointments with other practice staff are more likely to have a wait period of more than a day than
# those with a GP.  This could be a factor in why they are missed.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Non-Attended Appointments by HCP Type/Wait Time")
ax.set_xlabel("HCP Type")
ax.set_ylabel("Total Appointments")

sns.barplot(x='hcp_type', y='count_of_appointments', 
            hue='time_between_book_and_appointment', estimator=sum, data=no_attend)

fig.savefig('unattended_appointments_by_month_and_hcp.png')

# %%
# Data is further sub-set to see what mode the missed appointments take.

mode_status = no_attend.groupby(['icb_ons_code','appointment_month',
                                 'appointment_mode'])['count_of_appointments'].agg('sum').reset_index()
print(mode_status)
# Out:
#      icb_ons_code appointment_month appointment_mode  count_of_appointments
# 0       E54000008           2020-01     Face-to-Face                  54294
# 1       E54000008           2020-01       Home Visit                    412
# 2       E54000008           2020-01        Telephone                   7079
# 3       E54000008           2020-01          Unknown                   1293
# 4       E54000008           2020-01     Video/Online                     56
# ...           ...               ...              ...                    ...
# 6096    E54000062           2022-06     Face-to-Face                  30052
# 6097    E54000062           2022-06       Home Visit                    935
# 6098    E54000062           2022-06        Telephone                   5661
# 6099    E54000062           2022-06          Unknown                    151
# 6100    E54000062           2022-06     Video/Online                     99
#
# [6101 rows x 4 columns]

# %%
# The data is charted.  Face to face appointments have always been the most missed - this is not surprising 
# in real terms.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Total Non-Attended Appointments by Appointment Mode")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_mode', estimator=sum, 
             data=no_attend)

fig.savefig('unattended_appointments_by_month_and_mode.jpg')

# %%
# The data is further sub-set to only look at those that were face to face.

f2f_missed = mode_status[mode_status['appointment_mode'] == 'Face-to-Face']

print(f2f_missed)
# Out:
#      icb_ons_code appointment_month appointment_mode  count_of_appointments
# 0       E54000008           2020-01     Face-to-Face                  54294
# 5       E54000008           2020-02     Face-to-Face                  50789
# 10      E54000008           2020-03     Face-to-Face                  45834
# 15      E54000008           2020-04     Face-to-Face                  13355
# 20      E54000008           2020-05     Face-to-Face                  11684
# ...           ...               ...              ...                    ...
# 6076    E54000062           2022-02     Face-to-Face                  27869
# 6081    E54000062           2022-03     Face-to-Face                  33402
# 6086    E54000062           2022-04     Face-to-Face                  25645
# 6091    E54000062           2022-05     Face-to-Face                  30552
# 6096    E54000062           2022-06     Face-to-Face                  30052
#
# [1260 rows x 4 columns]

# %%
# ICB locations are then identified/counted within the face to face data.

missed_icb = f2f_missed.groupby(['icb_ons_code'])['count_of_appointments'].agg('sum').reset_index()

print(missed_icb)
# Out:
#    icb_ons_code  count_of_appointments
# 0     E54000008                1146186
# 1     E54000010                 500494
# 2     E54000011                 195514
# 3     E54000013                 315768
# 4     E54000015                 484689
# 5     E54000018                 433577
# 6     E54000019                 315304
# 7     E54000022                 449698
# 8     E54000023                 384611
# 9     E54000024                 406556
# 10    E54000025                 525416
# 11    E54000026                 333965
# 12    E54000027                1020122
# 13    E54000028                 611583
# 14    E54000029                 993172
# 15    E54000030                 701375
# 16    E54000031                 649185
# 17    E54000032                 766405
# 18    E54000034                 306943
# 19    E54000036                 316305
# 20    E54000037                 586147
# 21    E54000038                 227326
# 22    E54000039                 423821
# ...

# %%
# This data is further sub-set to just include the top 10 locations for missed face to face appointments.

f2f_loc_top = f2f_missed.groupby(['icb_ons_code'])['count_of_appointments'
                                                  ].agg('sum').sort_values(ascending=False).head(11).reset_index()

print(f2f_loc_top)
# Out:
#    icb_ons_code  count_of_appointments
# 0     E54000050                1378204
# 1     E54000057                1323100
# 2     E54000008                1146186
# 3     E54000054                1036391
# 4     E54000027                1020122
# 5     E54000029                 993172
# 6     E54000062                 770352
# 7     E54000032                 766405
# 8     E54000055                 723910
# 9     E54000048                 721709
# 10    E54000030                 701375

# %%
# These ICB codes are then used to filter the existing location_codes DataFrame.

top_missed_icb_names = location_codes[location_codes['icb_ons_code'].isin(['E54000050', 'E54000057',
                                                                         'E54000008', 'E54000054', 'E54000027',
                                                                         'E54000029', 'E54000062', 'E54000032',
                                                                         'E54000055', 'E54000048'])]
top_missed_icb_names
# Out:
#        icb_ons_code                       sub_icb_location_name
# 0         E54000050  NHS North East and North Cumbria ICB - 00L
# 1         E54000050  NHS North East and North Cumbria ICB - 00L
# 2         E54000050  NHS North East and North Cumbria ICB - 00L
# 3         E54000050  NHS North East and North Cumbria ICB - 00L
# 4         E54000050  NHS North East and North Cumbria ICB - 00L
# ...             ...                                         ...
# 817389    E54000054              NHS West Yorkshire ICB - X2C4Y
# 817390    E54000054              NHS West Yorkshire ICB - X2C4Y
# 817391    E54000054              NHS West Yorkshire ICB - X2C4Y
# 817392    E54000054              NHS West Yorkshire ICB - X2C4Y
# 817393    E54000054              NHS West Yorkshire ICB - X2C4Y
#
# [313946 rows x 2 columns]

# %%
# Then, this dataset is further cleaned to drop any duplicates and get a list of unique locations.
# These are the locations with the most missed appointments.
# The location with the fewest appointments (discovered earlier) is within this range.

unique_locs1 = top_missed_icb_names.drop_duplicates(['icb_ons_code','sub_icb_location_name'])

print(unique_locs1)
# Out:
#        icb_ons_code                       sub_icb_location_name
# 0         E54000050  NHS North East and North Cumbria ICB - 00L
# 6943      E54000050  NHS North East and North Cumbria ICB - 00N
# 11153     E54000050  NHS North East and North Cumbria ICB - 00P
# 16569     E54000048  NHS Lancashire and South Cumbria ICB - 00Q
# 21048     E54000048  NHS Lancashire and South Cumbria ICB - 00R
# 26464     E54000057            NHS Greater Manchester ICB - 00T
# 32924     E54000057            NHS Greater Manchester ICB - 00V
# 35094     E54000048  NHS Lancashire and South Cumbria ICB - 00X
# 40092     E54000057            NHS Greater Manchester ICB - 00Y
# 45911     E54000048  NHS Lancashire and South Cumbria ICB - 01A
# 51798     E54000057            NHS Greater Manchester ICB - 01D
# 56944     E54000048  NHS Lancashire and South Cumbria ICB - 01E
# 62822     E54000008       NHS Cheshire and Merseyside ICB - 01F
# 67122     E54000057            NHS Greater Manchester ICB - 01G
# ...

# %% [markdown]
# Further Exploration of the Locations with the Most and Least Appointments

# %%
# The code for the lowest appointment count location is identified.

lowest_apps_loc = location_codes[location_codes['sub_icb_location_name'
                                               ] == 'NHS Lancashire and South Cumbria ICB - 02G']

print(lowest_apps_loc.head(1))
# Out:
#        icb_ons_code                       sub_icb_location_name
# 130597    E54000048  NHS Lancashire and South Cumbria ICB - 02G

# %%
# The code is used to filter the ar DataFrame.

apps_in_lsc = ar[ar['icb_ons_code'] == 'E54000048']

print(apps_in_lsc.head())
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 158551    E54000048           2020-01           Attended       GP
# 158552    E54000048           2020-01           Attended       GP
# 158553    E54000048           2020-01           Attended       GP
# 158554    E54000048           2020-01           Attended       GP
# 158555    E54000048           2020-01           Attended       GP
#
#        appointment_mode time_between_book_and_appointment  \
# 158551     Face-to-Face                             1 Day
# 158552     Face-to-Face                    15  to 21 Days
# 158553     Face-to-Face                       2 to 7 Days
# 158554     Face-to-Face                    22  to 28 Days
# 158555     Face-to-Face                     8  to 14 Days
#
#         count_of_appointments
# 158551                   2149
# 158552                   1486
# 158553                   6767
# 158554                    679
# 158555                   4152

# %%
# The data is then filteres to only include the non-attended appointments.

apps_in_lsc_missed = apps_in_lsc[apps_in_lsc['appointment_status'] == 'DNA']

print(apps_in_lsc_missed.head())
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 158600    E54000048           2020-01                DNA       GP
# 158601    E54000048           2020-01                DNA       GP
# 158602    E54000048           2020-01                DNA       GP
# 158603    E54000048           2020-01                DNA       GP
# 158604    E54000048           2020-01                DNA       GP
#
#        appointment_mode time_between_book_and_appointment  \
# 158600     Face-to-Face                             1 Day
# 158601     Face-to-Face                    15  to 21 Days
# 158602     Face-to-Face                       2 to 7 Days
# 158603     Face-to-Face                    22  to 28 Days
# 158604     Face-to-Face                     8  to 14 Days
#
#         count_of_appointments
# 158600                    140
# 158601                     96
# 158602                    552
# 158603                     44
# 158604                    358

# %%
# The missed appointment data is aggregated by month and exported to csv to examine the figures.

missed_export = (apps_in_lsc_missed.groupby(['appointment_month'
                                 ])['count_of_appointments'].agg('sum').reset_index())

print(missed_export)

missed_export.to_csv("lancs_cumbria_missed.csv")
# Out:
#    appointment_month  count_of_appointments
# 0            2020-01                  35838
# 1            2020-02                  33623
# 2            2020-03                  32403
# 3            2020-04                  15543
# 4            2020-05                  15641
# 5            2020-06                  19478
# 6            2020-07                  22721
# 7            2020-08                  20827
# 8            2020-09                  37506
# 9            2020-10                  40774
# 10           2020-11                  29919
# 11           2020-12                  27914
# 12           2021-01                  24774
# 13           2021-02                  22221
# 14           2021-03                  28308
# 15           2021-04                  26496
# 16           2021-05                  27122
# 17           2021-06                  32360
# 18           2021-07                  32854
# 19           2021-08                  30340
# ...

# %%
# The data is then filtered again, this time to exclude unattended appointments.

apps_in_lsc_non_missed = apps_in_lsc[apps_in_lsc['appointment_status'] != 'DNA']

print(apps_in_lsc_non_missed.head())
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 158551    E54000048           2020-01           Attended       GP
# 158552    E54000048           2020-01           Attended       GP
# 158553    E54000048           2020-01           Attended       GP
# 158554    E54000048           2020-01           Attended       GP
# 158555    E54000048           2020-01           Attended       GP
#
#        appointment_mode time_between_book_and_appointment  \
# 158551     Face-to-Face                             1 Day
# 158552     Face-to-Face                    15  to 21 Days
# 158553     Face-to-Face                       2 to 7 Days
# 158554     Face-to-Face                    22  to 28 Days
# 158555     Face-to-Face                     8  to 14 Days
#
#         count_of_appointments
# 158551                   2149
# 158552                   1486
# 158553                   6767
# 158554                    679
# 158555                   4152

# %%
# This data is also exported to csv.

non_missed_export = apps_in_lsc_non_missed.groupby(['appointment_month'
                                 ])['count_of_appointments'].agg('sum').reset_index()

print(non_missed_export)

non_missed_export.to_csv("lancs_cumbria_non_missed.csv")
# Out:
#    appointment_month  count_of_appointments
# 0            2020-01                 725064
# 1            2020-02                 635292
# 2            2020-03                 623405
# 3            2020-04                 421499
# 4            2020-05                 440527
# 5            2020-06                 551812
# 6            2020-07                 608055
# 7            2020-08                 554479
# 8            2020-09                 755105
# 9            2020-10                 787916
# 10           2020-11                 702208
# 11           2020-12                 657002
# 12           2021-01                 641450
# 13           2021-02                 631926
# 14           2021-03                 758206
# 15           2021-04                 660686
# 16           2021-05                 641641
# 17           2021-06                 731616
# 18           2021-07                 710944
# 19           2021-08                 670803
# ...

# %%
# The same process is now followed for the top ICB location.
# The ar DataFrame is filtered for data relating only to that location.

apps_in_nwl = ar[ar['icb_ons_code'] == 'E54000027']

print(apps_in_nwl.head())
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 144538    E54000027           2020-01           Attended       GP
# 144539    E54000027           2020-01           Attended       GP
# 144540    E54000027           2020-01           Attended       GP
# 144541    E54000027           2020-01           Attended       GP
# 144542    E54000027           2020-01           Attended       GP
#
#        appointment_mode time_between_book_and_appointment  \
# 144538     Face-to-Face                             1 Day
# 144539     Face-to-Face                    15  to 21 Days
# 144540     Face-to-Face                       2 to 7 Days
# 144541     Face-to-Face                    22  to 28 Days
# 144542     Face-to-Face                     8  to 14 Days
#
#         count_of_appointments
# 144538                  29724
# 144539                  29946
# 144540                  81512
# 144541                  17557
# 144542                  57336

# %%
# The data for the location is exported to csv.
# The exported datasets were then combined to compare with GP numbers, to get an idea of utilisation
# of resources according to roughly how many appointments on average are handled by each GP.
# This is anecdotal only, given that only 'most' of the appointments appear to be handled by GPs.

all_nwl_export = apps_in_nwl.groupby(['appointment_month'
                                 ])['count_of_appointments'].agg('sum').reset_index()

print(all_nwl_export)

all_nwl_export.to_csv("all_nwl_by_month.csv")
# Out:
#    appointment_month  count_of_appointments
# 0            2020-01                 994700
# 1            2020-02                 913338
# 2            2020-03                 894707
# 3            2020-04                 599965
# 4            2020-05                 624021
# 5            2020-06                 796270
# 6            2020-07                 873049
# 7            2020-08                 777737
# 8            2020-09                1023450
# 9            2020-10                1051142
# 10           2020-11                 947263
# 11           2020-12                 888517
# 12           2021-01                 848612
# 13           2021-02                 863355
# 14           2021-03                1059461
# 15           2021-04                 958731
# 16           2021-05                 946845
# 17           2021-06                1103907
# 18           2021-07                1073307
# 19           2021-08                 981385
# ...

# %%
# Missed appointments for the lowest count location are plotted on a lineplot to look for any trends.
# A lot of appointments were missed in the winter - it is not clear why this might be from current data.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(10, 10)})
ax.set_title("Missed Appointments by Month - E54000048")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Total Appointments")
plt.xticks(rotation=90)

sns.lineplot(x='appointment_month', y='count_of_appointments', 
             estimator=sum, data=apps_in_lsc_missed, ci=None)
# Out:
# <AxesSubplot:title={'center':'Missed Appointments by Month - E54000048'}, xlabel='Appointment Month', ylabel='Total Appointments'>

# %% [markdown]
# Comparison of Appointment Wait Time and Missed Appointments

# %%
# The 10 locations with the worst attendance are sub-set and duplicates removed.

wait_time = ar.groupby(['icb_ons_code','time_between_book_and_appointment'
                       ])['count_of_appointments'].agg('sum').reset_index()

top_icb_wait = wait_time[wait_time['icb_ons_code'].isin(['E54000050', 'E54000057',
                                                                         'E54000008', 'E54000054', 'E54000027',
                                                                         'E54000029', 'E54000062', 'E54000032',
                                                                         'E54000055', 'E54000048'])]

unique_top_wait = top_icb_wait.drop_duplicates(['icb_ons_code','time_between_book_and_appointment'])

print(unique_top_wait)
# Out:
#     icb_ons_code time_between_book_and_appointment  count_of_appointments
# 0      E54000008                             1 Day                3383990
# 1      E54000008                    15  to 21 Days                1677630
# 2      E54000008                       2 to 7 Days                6653761
# 3      E54000008                    22  to 28 Days                 951927
# 4      E54000008                     8  to 14 Days                3565708
# ..           ...                               ...                    ...
# 331    E54000062                    22  to 28 Days                 424221
# 332    E54000062                     8  to 14 Days                1769804
# 333    E54000062                 More than 28 Days                 421811
# 334    E54000062                          Same Day                8631520
# 335    E54000062            Unknown / Data Quality                  10150
#
# [80 rows x 3 columns]

# %%
# A barplot is then created to visualise this.  Same Day is the largest category.
# Wait time doesn't appear to be a major factor in missed appointments at this location.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(20, 15)})
ax.set_title("Worst Locations for Non-Attendance by Appointment Wait Period")
ax.set_xlabel("Wait Period")
ax.set_ylabel("Total Missed Appointments")

sns.barplot(x='time_between_book_and_appointment', y='count_of_appointments', estimator=sum, 
            data=unique_top_wait)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')

# %%
# Locations with the least non-attendance are then sub-set.

f2f_loc_bottom = f2f_missed.groupby(['icb_ons_code'
                                    ])['count_of_appointments'
                                      ].agg('sum').sort_values(ascending=False).tail(11).reset_index()

print(f2f_loc_bottom)
# Out:
#    icb_ons_code  count_of_appointments
# 0     E54000040                 374447
# 1     E54000026                 333965
# 2     E54000036                 316305
# 3     E54000013                 315768
# 4     E54000019                 315304
# 5     E54000041                 310593
# 6     E54000034                 306943
# 7     E54000043                 269897
# 8     E54000059                 250334
# 9     E54000038                 227326
# 10    E54000011                 195514

# %%
# The top 10 locations are then filtered.

bottom_missed_icb_names = location_codes[location_codes['icb_ons_code'].isin(['E54000040', 'E54000026',
                                                                         'E54000036', 'E54000013', 'E54000019',
                                                                         'E54000041', 'E54000034', 'E54000043',
                                                                         'E54000059', 'E54000038'])]
bottom_missed_icb_names
# Out:
#        icb_ons_code              sub_icb_location_name
# 324349    E54000026  NHS Mid and South Essex ICB - 06Q
# 324350    E54000026  NHS Mid and South Essex ICB - 06Q
# 324351    E54000026  NHS Mid and South Essex ICB - 06Q
# 324352    E54000026  NHS Mid and South Essex ICB - 06Q
# 324353    E54000026  NHS Mid and South Essex ICB - 06Q
# ...             ...                                ...
# 764594    E54000034            NHS Frimley ICB - D4U1Y
# 764595    E54000034            NHS Frimley ICB - D4U1Y
# 764596    E54000034            NHS Frimley ICB - D4U1Y
# 764597    E54000034            NHS Frimley ICB - D4U1Y
# 764598    E54000034            NHS Frimley ICB - D4U1Y
#
# [118101 rows x 2 columns]

# %%
# Duplicate locations are then taken out.

unique_locs2 = bottom_missed_icb_names.drop_duplicates(['icb_ons_code','sub_icb_location_name'])

unique_locs2
# Out:
#        icb_ons_code                              sub_icb_location_name
# 324349    E54000026                  NHS Mid and South Essex ICB - 06Q
# 340944    E54000026                  NHS Mid and South Essex ICB - 07G
# 380466    E54000041                               NHS Dorset ICB - 11J
# 390982    E54000043                      NHS Gloucestershire ICB - 11M
# 400846    E54000036     NHS Cornwall and The Isles Of Scilly ICB - 11N
# 410084    E54000038                             NHS Somerset ICB - 11X
# 524858    E54000019     NHS Herefordshire and Worcestershire ICB - 18C
# 602803    E54000013                         NHS Lincolnshire ICB - 71E
# 621400    E54000059                     NHS Northamptonshire ICB - 78H
# 660047    E54000040  NHS Bath and North East Somerset Swindon and W...
# 702370    E54000026                  NHS Mid and South Essex ICB - 99E
# 710144    E54000026                  NHS Mid and South Essex ICB - 99F
# ...

# %%
# The data for the 10 locations is then aggregated with book/wait time and duplicates removed.

bottom_icb_wait = wait_time[wait_time['icb_ons_code'].isin(['E54000040', 'E54000026',
                                                                         'E54000036', 'E54000013', 'E54000019',
                                                                         'E54000041', 'E54000034', 'E54000043',
                                                                         'E54000059', 'E54000038'])]

unique_bottom_wait = bottom_icb_wait.drop_duplicates(['icb_ons_code','time_between_book_and_appointment'])

print(unique_bottom_wait)
# Out:
#     icb_ons_code time_between_book_and_appointment  count_of_appointments
# 24     E54000013                             1 Day                 731427
# 25     E54000013                    15  to 21 Days                 682196
# 26     E54000013                       2 to 7 Days                1930194
# 27     E54000013                    22  to 28 Days                 446473
# 28     E54000013                     8  to 14 Days                1291057
# ..           ...                               ...                    ...
# 307    E54000059                    22  to 28 Days                 281288
# 308    E54000059                     8  to 14 Days                1100809
# 309    E54000059                 More than 28 Days                 258879
# 310    E54000059                          Same Day                5024217
# 311    E54000059            Unknown / Data Quality                   1797
#
# [80 rows x 3 columns]

# %%
# A barplot is then created.  Locations with least non-attendance also show same day and 2 to 7 days as the most
# common categories.  This again suggests that wait time isn't generally a major factor.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(20, 25)})
ax.set_title("Locations with Least Non-Attendance by Appointment Wait Period")
ax.set_xlabel("Location Code")
ax.set_ylabel("Total Missed Appointments")

sns.barplot(x='time_between_book_and_appointment', y='count_of_appointments', estimator=sum, 
            data=unique_bottom_wait)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')

# %%
# Data for only non-attended appointments with Other Practice Staff are filtered and sub-set to compare with
# book/wait time.

no_attend_non_GP = no_attend[no_attend['hcp_type'] == 'Other Practice staff']

opt = no_attend_non_GP.groupby(['icb_ons_code','appointment_month',
                                'time_between_book_and_appointment'])[
    'count_of_appointments'].agg('sum').sort_values(ascending=False).reset_index()

opt.head()
# Out:
#   icb_ons_code appointment_month time_between_book_and_appointment  \
# 0    E54000008           2021-10                       2 to 7 Days
# 1    E54000050           2021-10                       2 to 7 Days
# 2    E54000057           2021-10                       2 to 7 Days
# 3    E54000057           2020-10                       2 to 7 Days
# 4    E54000057           2021-10                     8  to 14 Days
#
#    count_of_appointments
# 0                  19355
# 1                  18165
# 2                  17789
# 3                  16767
# 4                  16384

# %%
# The data is used to create a barplot showing wait time for missed Other Practice Staff appointments.
# There is more likely a wait of 2 to 14 days for these appointments and this may be a factor in why they are
# missed.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(15, 12)})
ax.set_title("Total Non-Attended 'Other Practice Staff' Appointments by Appointment Wait Period")
ax.set_xlabel("Time Between Book and Appointment")
ax.set_ylabel("Total Appointments")
sns.color_palette("colorblind")

sns.barplot(x='time_between_book_and_appointment', y='count_of_appointments', estimator=sum, 
            data=opt)

for bars in ax.containers:
    ax.bar_label(bars, fmt='%.0f')

# %% [markdown]
# Analysis of Health-Related Tweets

# %%
# tweets.csv is imported and sense-checked.

tweets = pd.read_csv('tweets.csv')

print(tweets.head())
# Out:
#               tweet_id                                    tweet_full_text  \
# 0  1567629223795527681  As Arkansas’ first Comprehensive Stroke Certif...
# 1  1567582846612553728  RT @AndreaGrammer: Work-life balance is at the...
# 2  1567582787070304256  RT @OntarioGreens: $10 billion can go a long w...
# 3  1567582767625428992  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies...
# 4  1567582720460570625  ICYMI: Our recent blogs on Cybersecurity in Ac...
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 1  {'hashtags': [{'text': 'PremiseHealth', 'indic...
# 2  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 3  {'hashtags': [{'text': 'NEW', 'indices': [20, ...
# 4  {'hashtags': [{'text': 'blogs', 'indices': [18...
#
#                              tweet_entities_hashtags  \
# 0                                        #Healthcare
# 1                            #PremiseHealth, #hiring
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# Retweets and favourited tweets are counted.

print(tweets['tweet_retweet_count'].value_counts())
print(tweets['tweet_favorite_count'].value_counts())
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %%
# The data is subset and sense-checked.

tweets_text = pd.read_csv('tweets.csv', usecols=['tweet_id','tweet_full_text','tweet_entities',
                            'tweet_entities_hashtags','tweet_metadata'])

tweets_text.head()
# Out:
#               tweet_id                                    tweet_full_text  \
# 0  1567629223795527681  As Arkansas’ first Comprehensive Stroke Certif...
# 1  1567582846612553728  RT @AndreaGrammer: Work-life balance is at the...
# 2  1567582787070304256  RT @OntarioGreens: $10 billion can go a long w...
# 3  1567582767625428992  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies...
# 4  1567582720460570625  ICYMI: Our recent blogs on Cybersecurity in Ac...
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 1  {'hashtags': [{'text': 'PremiseHealth', 'indic...
# 2  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 3  {'hashtags': [{'text': 'NEW', 'indices': [20, ...
# 4  {'hashtags': [{'text': 'blogs', 'indices': [18...
#
#                              tweet_entities_hashtags  \
# 0                                        #Healthcare
# 1                            #PremiseHealth, #hiring
# ...

# %%
# An empty list is created.
tags = []

# Hashtags are extracted from the 'tweet_full_text' column.
for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
# The extracted tweets are counted and added to the empty list as a Series.

tags = pd.Series(tags)

# %%
# The top 30 tags are shown.

tags.head(30)
# Out:
# 0                                    #healthcare
# 1                                 #premisehealth
# 2                                        #hiring
# 3                                    #healthcare
# 4                                        🚨#new:🚨
# 5                                look!\n\n#blogs
# 6                         #digitaltransformation
# 7                                 #cybersecurity
# 8                                    #accounting
# 9                                       #finance
# 10                                   #healthcare
# 11    https://t.co/jrgqeqdme4\n.\n#firstcoastcna
# 12                                      #cnaexam
# 13                           #cnaexampreparation
# 14                                 #jacksonville
# 15                                  #cnatraining
# 16                                        #nurse
# 17                                      #nursing
# 18                                    #nurselife
# ...

# %%
# The series is converted to a DataFrame and tidied up:

top_tweets['hashtags'] = pd.DataFrame(tags)

top_tweets.head()
# Out:
#                 0        hashtags
# 0     #healthcare     #healthcare
# 1  #premisehealth  #premisehealth
# 2         #hiring         #hiring
# 3     #healthcare     #healthcare
# 4         🚨#new:🚨         🚨#new:🚨

# %%
top_tweets = top_tweets.drop(top_tweets.columns[0], axis=1)
top_tweets.head()
# Out:
#          hashtags
# 0     #healthcare
# 1  #premisehealth
# 2         #hiring
# 3     #healthcare
# 4         🚨#new:🚨

# %%
# The tags are converted to str format and the top 10 tweets are identified:

top_tweets = top_tweets.astype('str')
top_tweets = top_tweets.value_counts()

top_tweets.head(10)
# Out:
# hashtags
# #healthcare        716
# #health             80
# #medicine           41
# #ai                 40
# #job                38
# #medical            35
# #strategy           30
# #pharmaceutical     28
# #digitalhealth      25
# #marketing          25
# dtype: int64

# %%
# ar DataFrame sub-set.

ar_agg = ar.groupby(['icb_ons_code','appointment_month','appointment_status', 'hcp_type', 'appointment_mode',
                    'time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()

print(ar_agg.head())
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000008           2020-01           Attended       GP     Face-to-Face
# 1    E54000008           2020-01           Attended       GP     Face-to-Face
# 2    E54000008           2020-01           Attended       GP     Face-to-Face
# 3    E54000008           2020-01           Attended       GP     Face-to-Face
# 4    E54000008           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                  32181
# 1                    15  to 21 Days                  23190
# 2                       2 to 7 Days                  83788
# 3                    22  to 28 Days                  16172
# 4                     8  to 14 Days                  53405

# %%
top_10.rename(columns={['count_of_hashtags']}, inplace=True)
top_10.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [194], in <cell line: 1>()
# ----> 1 top_10.rename(columns={['count_of_hashtags']}, inplace=True)
#       2 top_10.head()
#
# TypeError: unhashable type: 'list'

# %%
# The data is then grouped by month and count of appointment in another sub-set and sense-checked.

ar_month = ar_agg.groupby(['appointment_month'])['count_of_appointments'].agg('sum').reset_index()

print(ar_month.head())
# Out:
#   appointment_month  count_of_appointments
# 0           2020-01               27199296
# 1           2020-02               24104621
# 2           2020-03               24053468
# 3           2020-04               16007881
# 4           2020-05               16417212

# %% [markdown]
# Actual Utilisation of Resources

# %%
# A new column is added to the DataFrame to show the average daily count of appointments, rounded to one
# decimal place.

ar_month['utilisation'] = (ar_month['count_of_appointments']/30).round(1)

# The data is sense-checked.
print(ar_month.head())
# Out:
#   appointment_month  count_of_appointments  utilisation
# 0           2020-01               27199296     906643.2
# 1           2020-02               24104621     803487.4
# 2           2020-03               24053468     801782.3
# 3           2020-04               16007881     533596.0
# 4           2020-05               16417212     547240.4

# %%
# The month columns in both datasets are changed to object to assist with plotting.

ar_agg['appointment_month'] = ar_agg['appointment_month'].astype('object')
ar_month['appointment_month'] = ar_month['appointment_month'].astype('object')

# %%
# The monthly appointments are plotted on a line plot.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(12, 15)})
ax.set_title("Monthly Appointments Vs. Monthly Capacity")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments")
plt.xticks(rotation=90)
# A line is added to show the monthly capacity of the NHS (360000000 appointments).
plt.axhline(y=36000000, color='r', linestyle='--')

sns.lineplot(x='appointment_month', y='count_of_appointments', estimator=sum, 
             data=ar_agg)
# Out:
# <AxesSubplot:title={'center':'Monthly Appointments Vs. Monthly Capacity'}, xlabel='Appointment Month', ylabel='Count of Appointments'>

# %%
# A second visualisation is created showing average daily appointments.
# Both charts indicate that overall, actual utilisation is below capacity, but this generalisation doesn't take
# individual characteristics of ICBs (e.g. population they serve, staff numbers) into account.

fig, ax = plt.subplots(dpi=150)

sns.set(rc = {'figure.figsize':(12, 15)})
ax.set_title("Average Daily Appointments Vs. Daily Capacity")
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments")
plt.xticks(rotation=90)
# A line is added to show the daily capacity of the NHS (1200000 appointments).
plt.axhline(y=1200000, color='r', linestyle='--')

sns.lineplot(x='appointment_month', y='utilisation', estimator=sum, 
             data=ar_month)

fig.savefig('daily_appointments_vs_capacity.png')
